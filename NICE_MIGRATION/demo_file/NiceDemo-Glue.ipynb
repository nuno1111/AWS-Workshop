# %%
# %%configure --name project.spark.compatibility
# {
#     "--datalake-formats": "iceberg",
#     "--conf": "spark.sql.catalog.glue_catalog=org.apache.iceberg.spark.SparkCatalog --conf spark.sql.catalog.glue_catalog.type=glue --conf spark.sql.defaultCatalog=glue_catalog"
# }
# Out:
# Executing for connection type: SPARK_GLUE, connection name: project.spark.compatibility
# "The following configurations have been updated: {'--datalake-formats': 'iceberg', '--conf': 'spark.sql.catalog.glue_catalog=org.apache.iceberg.spark.SparkCatalog --conf spark.sql.catalog.glue_catalog.type=glue --conf spark.sql.defaultCatalog=glue_catalog'}"

# %%
# %%pyspark project.spark.compatibility
# df = spark.sql("""
# select * from nice_database.tbkbcard_medi_store limit 10
# """).show()
# Out:
# Creating Glue session...
# Create session for connection: project.spark.compatibility
# 'Session 460zft6y2vswig-98b8cf46-3a11-4cc7-a5a4-87b3b012e28f has been created.'
#                 <table class="session_info_table" style="width: 75%; margin-top: var(--jp-content-heading-margin-top); margin-bottom:var(--jp-content-heading-margin-bottom); border: var(--jp-border-width) solid var(--jp-border-color2);">
#                     <tr>
#                         <th style="text-align: left; border: var(--jp-border-width) solid var(--jp-border-color2);">Id</th>
#                         <th style="text-align: left; border: var(--jp-border-width) solid var(--jp-border-color2);">Spark UI</th>
#                         <th style="text-align: left; border: var(--jp-border-width) solid var(--jp-border-color2);">Driver logs</th>
#                     </tr>
#                     <tr>
# ...

# %%
# %%pyspark project.spark.compatibility
# df = spark.sql("""
# select * from spark_catalog.it_team_db_axpifoaredfteg.sample_table limit 10
# """).show()
# Out:
# +-------+---+----------+
# |   name|age|department|
# +-------+---+----------+
# |Charlie| 35|   Finance|
# |  Alice| 25|        HR|
# |    Bob| 30|        IT|
# +-------+---+----------+
# Connection: project.spark.compatibility | Run start time: 2025-09-07 06:53:10.967664 | Run duration : 0:00:09.101494s.
